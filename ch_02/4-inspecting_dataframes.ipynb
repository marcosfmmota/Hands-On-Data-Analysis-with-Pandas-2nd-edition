# %% [markdown]
# # Inspecting a DataFrame Object
#
# ## About the Data
# In this notebook, we will be working with earthquake data from September 18, 2018 - October 13, 2018 (obtained from the US Geological Survey (USGS) using the [USGS API](https://earthquake.usgs.gov/fdsnws/event/1/))
#
# ## Setup
# We will be working with the `data/earthquakes.csv` file again, so we need to handle our imports and read it in.

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('earthquakes.csv')

# %% [markdown]
# ## Examining dataframes
# ### Is it empty?

# %%
df.empty
# Out:
# False

# %% [markdown]
# ### What are the dimensions?

# %%
df.shape
# Out:
# (10232, 26)

# %% [markdown]
# ### What columns do we have?
# We know there are 26 columns, but what are they? Let's use the `columns` attribute to see:

# %%
df.columns
# Out:
# Index(['mag', 'place', 'time', 'updated', 'tz', 'url', 'detail', 'felt', 'cdi',
#        'mmi', 'alert', 'status', 'tsunami', 'sig', 'net', 'code', 'ids',
#        'sources', 'types', 'nst', 'dmin', 'rms', 'gap', 'magType', 'type',
#        'title'],
#       dtype='object')

# %% [markdown]
# ### What does the data look like?
# View rows from the top with `head()`:

# %%
df.head()
# Out:
#     mag                                              place           time  \
# 0  2.00                          23 km N of Willow, Alaska  1622332708509
# 1  0.35                           2km N of The Geysers, CA  1622331217450
# 2  4.50    91 km W of San Antonio de los Cobres, Argentina  1622330654734
# 3  2.16                             18km E of Ocotillo, CA  1622330638080
# 4  4.40  115 km WNW of San Antonio de los Cobres, Argen...  1622330295993
#
#          updated  tz                                                url  \
# 0  1622333534854 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  1622338572406 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  1622398852359 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  1622330856366 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  1622332202040 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                               detail  felt  cdi  mmi  ...  \
# 0  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 1  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 2  https://earthquake.usgs.gov/fdsnws/event/1/que...   1.0  1.0  NaN  ...
# 3  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 4  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
#
#               ids sources                                           types  \
# 0  ,ak0216ut468m,    ,ak,                                        ,origin,
# 1    ,nc73567366,    ,nc,  ,nearby-cities,origin,phase-data,scitech-link,
# 2    ,us6000efw3,    ,us,                        ,dyfi,origin,phase-data,
# 3    ,ci39909792,    ,ci,  ,nearby-cities,origin,phase-data,scitech-link,
# 4    ,us6000efw1,    ,us,                             ,origin,phase-data,
#
#     nst      dmin   rms    gap magType        type  \
# 0   NaN       NaN  0.62    NaN      ml  earthquake
# 1  14.0  0.005785  0.02  120.0      md  earthquake
# 2   NaN  1.451000  0.51  106.0      mb  earthquake
# 3  25.0  0.092780  0.28   57.0      ml  earthquake
# 4   NaN  1.111000  0.44  100.0      mb  earthquake
#
#                                                title
# 0                  M 2.0 - 23 km N of Willow, Alaska
# 1                   M 0.4 - 2km N of The Geysers, CA
# 2  M 4.5 - 91 km W of San Antonio de los Cobres, ...
# 3                     M 2.2 - 18km E of Ocotillo, CA
# 4  M 4.4 - 115 km WNW of San Antonio de los Cobre...
#
# [5 rows x 26 columns]

# %% [markdown]
# View rows from the bottom with `tail()`. Let's view 2 rows:

# %%
df.tail(2)
# Out:
#         mag                      place           time        updated  tz  \
# 10230  0.89  15km E of Seven Trees, CA  1619741326460  1619753767570 NaN
# 10231  0.15  6km NW of The Geysers, CA  1619740962850  1619741059078 NaN
#
#                                                      url  \
# 10230  https://earthquake.usgs.gov/earthquakes/eventp...
# 10231  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                                   detail  felt  cdi  mmi  ...  \
# 10230  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 10231  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
#
#                 ids sources                              types   nst  \
# 10230  ,nc73556285,    ,nc,  ,nearby-cities,origin,phase-data,  17.0
# 10231  ,nc73556280,    ,nc,  ,nearby-cities,origin,phase-data,  11.0
#
#            dmin   rms   gap magType        type  \
# 10230  0.029410  0.06  56.0      md  earthquake
# 10231  0.006624  0.02  64.0      md  earthquake
#
#                                    title
# 10230  M 0.9 - 15km E of Seven Trees, CA
# 10231  M 0.2 - 6km NW of The Geysers, CA
#
# [2 rows x 26 columns]

# %%
pd.set_option('display.max_columns', 26)
df.head()
# Out:
#     mag                                              place           time  \
# 0  2.00                          23 km N of Willow, Alaska  1622332708509
# 1  0.35                           2km N of The Geysers, CA  1622331217450
# 2  4.50    91 km W of San Antonio de los Cobres, Argentina  1622330654734
# 3  2.16                             18km E of Ocotillo, CA  1622330638080
# 4  4.40  115 km WNW of San Antonio de los Cobres, Argen...  1622330295993
#
#          updated  tz                                                url  \
# 0  1622333534854 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  1622338572406 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  1622398852359 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  1622330856366 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  1622332202040 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                               detail  felt  cdi  mmi alert  \
# 0  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN   NaN
# 1  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN   NaN
# 2  https://earthquake.usgs.gov/fdsnws/event/1/que...   1.0  1.0  NaN   NaN
# 3  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN   NaN
# 4  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN   NaN
#
#       status  tsunami  sig net        code             ids sources  \
# 0  automatic        0   62  ak  0216ut468m  ,ak0216ut468m,    ,ak,
# 1  automatic        0    2  nc    73567366    ,nc73567366,    ,nc,
# 2   reviewed        0  312  us    6000efw3    ,us6000efw3,    ,us,
# 3  automatic        0   72  ci    39909792    ,ci39909792,    ,ci,
# 4   reviewed        0  298  us    6000efw1    ,us6000efw1,    ,us,
#
#                                             types   nst      dmin   rms  \
# 0                                        ,origin,   NaN       NaN  0.62
# 1  ,nearby-cities,origin,phase-data,scitech-link,  14.0  0.005785  0.02
# 2                        ,dyfi,origin,phase-data,   NaN  1.451000  0.51
# 3  ,nearby-cities,origin,phase-data,scitech-link,  25.0  0.092780  0.28
# 4                             ,origin,phase-data,   NaN  1.111000  0.44
#
#      gap magType        type  \
# 0    NaN      ml  earthquake
# 1  120.0      md  earthquake
# 2  106.0      mb  earthquake
# 3   57.0      ml  earthquake
# 4  100.0      mb  earthquake
#
#                                                title
# 0                  M 2.0 - 23 km N of Willow, Alaska
# 1                   M 0.4 - 2km N of The Geysers, CA
# 2  M 4.5 - 91 km W of San Antonio de los Cobres, ...
# 3                     M 2.2 - 18km E of Ocotillo, CA
# 4  M 4.4 - 115 km WNW of San Antonio de los Cobre...

# %%
pd.reset_option('display.max_columns')
df.head()
# Out:
#     mag                                              place           time  \
# 0  2.00                          23 km N of Willow, Alaska  1622332708509
# 1  0.35                           2km N of The Geysers, CA  1622331217450
# 2  4.50    91 km W of San Antonio de los Cobres, Argentina  1622330654734
# 3  2.16                             18km E of Ocotillo, CA  1622330638080
# 4  4.40  115 km WNW of San Antonio de los Cobres, Argen...  1622330295993
#
#          updated  tz                                                url  \
# 0  1622333534854 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  1622338572406 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  1622398852359 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  1622330856366 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  1622332202040 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                               detail  felt  cdi  mmi  ...  \
# 0  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 1  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 2  https://earthquake.usgs.gov/fdsnws/event/1/que...   1.0  1.0  NaN  ...
# 3  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 4  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
#
#               ids sources                                           types  \
# 0  ,ak0216ut468m,    ,ak,                                        ,origin,
# 1    ,nc73567366,    ,nc,  ,nearby-cities,origin,phase-data,scitech-link,
# 2    ,us6000efw3,    ,us,                        ,dyfi,origin,phase-data,
# 3    ,ci39909792,    ,ci,  ,nearby-cities,origin,phase-data,scitech-link,
# 4    ,us6000efw1,    ,us,                             ,origin,phase-data,
#
#     nst      dmin   rms    gap magType        type  \
# 0   NaN       NaN  0.62    NaN      ml  earthquake
# 1  14.0  0.005785  0.02  120.0      md  earthquake
# 2   NaN  1.451000  0.51  106.0      mb  earthquake
# 3  25.0  0.092780  0.28   57.0      ml  earthquake
# 4   NaN  1.111000  0.44  100.0      mb  earthquake
#
#                                                title
# 0                  M 2.0 - 23 km N of Willow, Alaska
# 1                   M 0.4 - 2km N of The Geysers, CA
# 2  M 4.5 - 91 km W of San Antonio de los Cobres, ...
# 3                     M 2.2 - 18km E of Ocotillo, CA
# 4  M 4.4 - 115 km WNW of San Antonio de los Cobre...
#
# [5 rows x 26 columns]

# %% [markdown]
# *Tip: we can modify the display options in order to see more columns:*
#
# ```python
# # check the max columns setting
# >>> pd.get_option('display.max_columns')
# 20
#
# # set the max columns to show when printing the dataframe to 26
# >>> pd.set_option('display.max_columns', 26)
# # OR
# >>> pd.options.display.max_columns = 26
#
# # reset the option
# >>> pd.reset_option('display.max_columns')
#
# # get information on all display settings
# >>> pd.describe_option('display')
# ```
#
# *More information can be found in the documentation [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/options.html).*
#
# ### What data types do we have?

# %%
df.dtypes
# Out:
# mag        float64
# place       object
# time         int64
# updated      int64
# tz         float64
# url         object
# detail      object
# felt       float64
# cdi        float64
# mmi        float64
# alert       object
# status      object
# tsunami      int64
# sig          int64
# net         object
# code        object
# ids         object
# sources     object
# types       object
# nst        float64
# dmin       float64
# rms        float64
# gap        float64
# magType     object
# type        object
# title       object
# dtype: object

# %% [markdown]
# ### Getting extra info and finding nulls

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10232 entries, 0 to 10231
# Data columns (total 26 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   mag      10232 non-null  float64
#  1   place    10232 non-null  object
#  2   time     10232 non-null  int64
#  3   updated  10232 non-null  int64
#  4   tz       0 non-null      float64
#  5   url      10232 non-null  object
#  6   detail   10232 non-null  object
#  7   felt     540 non-null    float64
#  8   cdi      540 non-null    float64
#  9   mmi      85 non-null     float64
#  10  alert    51 non-null     object
#  11  status   10232 non-null  object
#  12  tsunami  10232 non-null  int64
#  13  sig      10232 non-null  int64
#  14  net      10232 non-null  object
#  15  code     10232 non-null  object
#  16  ids      10232 non-null  object
#  17  sources  10232 non-null  object
#  18  types    10232 non-null  object
#  19  nst      7544 non-null   float64
#  20  dmin     7075 non-null   float64
#  21  rms      10232 non-null  float64
#  22  gap      8602 non-null   float64
#  23  magType  10232 non-null  object
#  24  type     10232 non-null  object
#  25  title    10232 non-null  object
# dtypes: float64(9), int64(4), object(13)
# memory usage: 2.0+ MB

# %% [markdown]
# ## Describing and Summarizing
# ### Get summary statistics

# %%
df.describe()
# Out:
#                 mag          time       updated   tz         felt         cdi  \
# count  10232.000000  1.023200e+04  1.023200e+04  0.0   540.000000  540.000000
# mean       1.585611  1.621042e+12  1.621296e+12  NaN    42.598148    2.855926
# std        1.210489  7.388416e+08  7.075837e+08  NaN   382.036385    1.423270
# min       -1.290000  1.619741e+12  1.619741e+12  NaN     0.000000    0.000000
# 25%        0.850000  1.620398e+12  1.620744e+12  NaN     1.000000    2.000000
# 50%        1.360000  1.621028e+12  1.621522e+12  NaN     2.000000    2.700000
# 75%        2.000000  1.621726e+12  1.621894e+12  NaN     6.000000    3.600000
# max        7.300000  1.622333e+12  1.622489e+12  NaN  8284.000000    9.100000
#
#              mmi       tsunami           sig          nst         dmin  \
# count  85.000000  10232.000000  10232.000000  7544.000000  7075.000000
# mean    3.741165      0.000391     61.697224    21.401246     0.586679
# std     1.745962      0.019769     94.278662    15.917219     2.043666
# min     0.000000      0.000000      0.000000     2.000000     0.000000
# 25%     3.233000      0.000000     11.000000    10.000000     0.025000
# 50%     3.759000      0.000000     28.000000    17.000000     0.073190
# 75%     4.344000      0.000000     62.000000    28.000000     0.167384
# max     9.000000      1.000000   1072.000000   171.000000    35.302000
#
#                 rms          gap
# count  10232.000000  8602.000000
# mean       0.282517   119.039631
# std        0.292542    64.811104
# min        0.000000     9.000000
# 25%        0.090000    68.000000
# 50%        0.160000   105.000000
# 75%        0.360000   151.000000
# max        2.680000   360.000000

# %% [markdown]
# Specifying the 5<sup>th</sup> and 95<sup>th</sup> percentile:

# %%
df.describe(percentiles=[0.05, 0.95])
# Out:
#                 mag          time       updated   tz         felt         cdi  \
# count  10232.000000  1.023200e+04  1.023200e+04  0.0   540.000000  540.000000
# mean       1.585611  1.621042e+12  1.621296e+12  NaN    42.598148    2.855926
# std        1.210489  7.388416e+08  7.075837e+08  NaN   382.036385    1.423270
# min       -1.290000  1.619741e+12  1.619741e+12  NaN     0.000000    0.000000
# 5%         0.080000  1.619877e+12  1.620069e+12  NaN     1.000000    1.000000
# 50%        1.360000  1.621028e+12  1.621522e+12  NaN     2.000000    2.700000
# 95%        4.400000  1.622174e+12  1.622249e+12  NaN   156.350000    5.400000
# max        7.300000  1.622333e+12  1.622489e+12  NaN  8284.000000    9.100000
#
#              mmi       tsunami           sig          nst         dmin  \
# count  85.000000  10232.000000  10232.000000  7544.000000  7075.000000
# mean    3.741165      0.000391     61.697224    21.401246     0.586679
# std     1.745962      0.019769     94.278662    15.917219     2.043666
# min     0.000000      0.000000      0.000000     2.000000     0.000000
# 5%      0.000000      0.000000      0.000000     5.000000     0.006526
# 50%     3.759000      0.000000     28.000000    17.000000     0.073190
# 95%     6.549200      0.000000    298.000000    52.000000     3.295000
# max     9.000000      1.000000   1072.000000   171.000000    35.302000
#
#                 rms          gap
# count  10232.000000  8602.000000
# mean       0.282517   119.039631
# std        0.292542    64.811104
# min        0.000000     9.000000
# 5%         0.020000    43.000000
# 50%        0.160000   105.000000
# 95%        0.900000   254.000000
# max        2.680000   360.000000

# %% [markdown]
# Describe specific data types:

# %%
df.describe(include=np.object)
# Out:
#                             place  \
# count                       10232
# unique                       5173
# top     7km NW of The Geysers, CA
# freq                          120
#
#                                                       url  \
# count                                               10232
# unique                                              10232
# top     https://earthquake.usgs.gov/earthquakes/eventp...
# freq                                                    1
#
#                                                    detail  alert    status  \
# count                                               10232     51     10232
# unique                                              10232      3         2
# top     https://earthquake.usgs.gov/fdsnws/event/1/que...  green  reviewed
# freq                                                    1     48      7094
#
#           net      code           ids sources                types magType  \
# count   10232     10232         10232   10232                10232   10232
# unique     15     10229         10232      67                   46       8
# top        nc  2021jzan  ,mb80502414,    ,nc,  ,origin,phase-data,      ml
# freq     1912         2             1    1782                 4846    6443
#
#               type                              title
# count        10232                              10232
# unique           4                               8301
# top     earthquake  M 0.9 - 8km NW of The Geysers, CA
# freq         10031                                 39

# %% [markdown]
# Or describe all of them:

# %%
df.describe(include='all')
# Out:
#                  mag                      place          time       updated  \
# count   10232.000000                      10232  1.023200e+04  1.023200e+04
# unique           NaN                       5173           NaN           NaN
# top              NaN  7km NW of The Geysers, CA           NaN           NaN
# freq             NaN                        120           NaN           NaN
# mean        1.585611                        NaN  1.621042e+12  1.621296e+12
# std         1.210489                        NaN  7.388416e+08  7.075837e+08
# min        -1.290000                        NaN  1.619741e+12  1.619741e+12
# 25%         0.850000                        NaN  1.620398e+12  1.620744e+12
# 50%         1.360000                        NaN  1.621028e+12  1.621522e+12
# 75%         2.000000                        NaN  1.621726e+12  1.621894e+12
# max         7.300000                        NaN  1.622333e+12  1.622489e+12
#
#          tz                                                url  \
# count   0.0                                              10232
# unique  NaN                                              10232
# top     NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# freq    NaN                                                  1
# mean    NaN                                                NaN
# std     NaN                                                NaN
# min     NaN                                                NaN
# 25%     NaN                                                NaN
# 50%     NaN                                                NaN
# 75%     NaN                                                NaN
# max     NaN                                                NaN
#
#                                                    detail         felt  \
# count                                               10232   540.000000
# unique                                              10232          NaN
# top     https://earthquake.usgs.gov/fdsnws/event/1/que...          NaN
# freq                                                    1          NaN
# mean                                                  NaN    42.598148
# std                                                   NaN   382.036385
# min                                                   NaN     0.000000
# 25%                                                   NaN     1.000000
# 50%                                                   NaN     2.000000
# 75%                                                   NaN     6.000000
# max                                                   NaN  8284.000000
#
#                cdi        mmi  ...           ids sources                types  \
# count   540.000000  85.000000  ...         10232   10232                10232
# unique         NaN        NaN  ...         10232      67                   46
# top            NaN        NaN  ...  ,mb80502414,    ,nc,  ,origin,phase-data,
# freq           NaN        NaN  ...             1    1782                 4846
# mean      2.855926   3.741165  ...           NaN     NaN                  NaN
# std       1.423270   1.745962  ...           NaN     NaN                  NaN
# min       0.000000   0.000000  ...           NaN     NaN                  NaN
# 25%       2.000000   3.233000  ...           NaN     NaN                  NaN
# 50%       2.700000   3.759000  ...           NaN     NaN                  NaN
# 75%       3.600000   4.344000  ...           NaN     NaN                  NaN
# max       9.100000   9.000000  ...           NaN     NaN                  NaN
#
#                 nst         dmin           rms          gap magType  \
# count   7544.000000  7075.000000  10232.000000  8602.000000   10232
# unique          NaN          NaN           NaN          NaN       8
# top             NaN          NaN           NaN          NaN      ml
# freq            NaN          NaN           NaN          NaN    6443
# mean      21.401246     0.586679      0.282517   119.039631     NaN
# std       15.917219     2.043666      0.292542    64.811104     NaN
# min        2.000000     0.000000      0.000000     9.000000     NaN
# 25%       10.000000     0.025000      0.090000    68.000000     NaN
# 50%       17.000000     0.073190      0.160000   105.000000     NaN
# 75%       28.000000     0.167384      0.360000   151.000000     NaN
# max      171.000000    35.302000      2.680000   360.000000     NaN
#
#               type                              title
# count        10232                              10232
# unique           4                               8301
# top     earthquake  M 0.9 - 8km NW of The Geysers, CA
# freq         10031                                 39
# mean           NaN                                NaN
# std            NaN                                NaN
# min            NaN                                NaN
# 25%            NaN                                NaN
# 50%            NaN                                NaN
# 75%            NaN                                NaN
# max            NaN                                NaN
#
# [11 rows x 26 columns]

# %% [markdown]
# This works on columns also:

# %%
df.felt.describe()
# Out:
# count     540.000000
# mean       42.598148
# std       382.036385
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         6.000000
# max      8284.000000
# Name: felt, dtype: float64

# %% [markdown]
# There are methods for specific statistics as well. Here is a sampling of them:
#
# | Method | Description | Data types |
# | --- | --- | --- |
# | `count()` | The number of non-null observations | Any |
# | `nunique()` | The number of unique values | Any |
# | `sum()` | The total of the values | Numerical or Boolean |
# | `mean()` | The average of the values | Numerical or Boolean |
# | `median()` | The median of the values | Numerical |
# | `min()` | The minimum of the values | Numerical |
# | `idxmin()` | The index where the minimum values occurs | Numerical |
# | `max()` | The maximum of the values | Numerical |
# | `idxmax()` | The index where the maximum value occurs | Numerical |
# | `abs()` | The absolute values of the data | Numerical |
# | `std()` | The standard deviation | Numerical |
# | `var()` | The variance |  Numerical |
# | `cov()` | The covariance between two `Series`, or a covariance matrix for all column combinations in a `DataFrame` | Numerical |
# | `corr()` | The correlation between two `Series`, or a correlation matrix for all column combinations in a `DataFrame` | Numerical |
# | `quantile()` | Calculates a specific quantile | Numerical |
# | `cumsum()` | The cumulative sum | Numerical or Boolean |
# | `cummin()` | The cumulative minimum | Numerical |
# | `cummax()` | The cumulative maximum | Numerical |
#
# For example, finding the unique values in the `alert` column:

# %%
df.alert.unique()
# Out:
# array([nan, 'green', 'yellow', 'orange'], dtype=object)

# %% [markdown]
# We can then use `value_counts()` to see how many of each unique value we have:

# %%
df.alert.value_counts()
# Out:
# green     48
# orange     2
# yellow     1
# Name: alert, dtype: int64

# %% [markdown]
# Note that `Index` objects also have several methods to help describe and summarize our data:
#
# | Method | Description |
# | --- | --- |
# | `argmax()`/`argmin()` | Find the location of the maximum/minimum value in the index |
# | `equals()` | Compare the index to another `Index` object for equality |
# | `isin()` | Check if the index values are in a list of values and return an array of Booleans |
# | `max()`/`min()` | Find the maximum/minimum value in the index |
# | `nunique()` | Get the number of unique values in the index |
# | `to_series()` | Create a `Series` object from the index |
# | `unique()` | Find the unique values of the index |
# | `value_counts()`| Create a frequency table for the unique values in the index |

# %% [markdown]
# <hr>
# <div>
#     <a href="./3-making_dataframes_from_api_requests.ipynb">
#         <button style="float: left;">&#8592; Previous Notebook</button>
#     </a>
#     <a href="./5-subsetting_data.ipynb">
#         <button style="float: right;">Next Notebook &#8594;</button>
#     </a>
# </div>
# <br>
# <hr>
